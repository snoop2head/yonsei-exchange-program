# %% [markdown]
# ## Import modules and EDA

# %%
# 출력이 너무 길어지지 않게하기 위해 찍지 않도록 했으나 
# 실제 학습 할 때는 아래 두 줄을 주석처리 하는 것을 권장한다.
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
print(pd.__version__)
print(np.__version__)
# Out:
# 1.0.5
# 1.18.5

# %%
# pandas 설정: 모든 row와 모든 column을 출력하게 하고, 각 column 별 출력되는 글자수는 50자 이내
pd.set_option('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', 50)

# %%
# 위의 설정으로 간단하게 보는 df_specific
df_specific = pd.read_csv("./data_wrangled/df_specific_wrangle.csv", encoding="utf-8")
df_specific.head(3)
# Out:
#        대학코드                             대학명  \
# 0  AR000004        Universidad del Salvador
# 1  AU000019  Australian National University
# 2  AU000001                 Bond University
#
#                                             gen_info  \
# 0  아르헨티나의 대다수 대학교는 한국처럼 캠퍼스가 있는 것이 아니라 도시 내에 몇개의 ...
# 1  ANU has a very big campus, but unlike Yonsei, ...
# 2  Bond대학교는 휴양지로 유명한 골드코스트에 위치해있습니다. 서퍼스 파라다이스, 브...
#
#                                             env_info  \
# 0  대학교가 도시 여러곳에 분포하고 있으므로 각기 다르다. 하지만 남녀를 불문하고 부에...
# 1  The city center, called CIVIC, is 20min walk a...
# 2  학교 주변은 조용하고 깨끗한 평화로운 전원마을의 느낌입니다. 학교에서 5분정도 걸어...
#
#                                            food_info  \
# 0  기숙사는 학교에서 제공하지 않고 두가지 옵션이 주어진다. 홈스테이 혹은 게스트 하우...
# 1  There are many housing options, but I chose to...
# 2  거주형태는 크게 On Campus와 Off Campus로 나뉩니다. 저는 기숙사에 ...
#
#                                           study_info  \
# 0  아르헨티나에서의 대학 수업은 주로 오전 혹은 저녁에 있다. 대부분의 학생들이 일을하...
# 1  In my personal opinions, classes are generally...
# 2  수업은 보통 4개의 수업을 듣습니다. 저는 Chinese1, Australian p...
#
#                                          office_info  \
# 0  EL SALVADOR대학교는 국제 교육부가 잘 되있는 학교이다. 아르헨티나 대학교들...
# 1  Overall, I did not have to ask for help much f...
# 2  교환생활 중 국제교육부와 연락할 일은 없었습니다. 교환학생을 가서 따로 국제교육부와...
#
#                                           facil_info  \
# 0  부대시설로는 헬스장이 있다고 알고 있으나 시내와 먼 곳에 있었다. 동아리는 몇가지 ...
# 1  There were many clubs for you to join at ANU, ...
# 2  학기초에 동아리 박람회식으로 여러 동아리들의 부스가 세워집니다. 관심 있는 동아리에...
#
#                                            mhct_info  \
# 0  딱히 컬쳐쇼크를 받을 만 한 요소는 없었던 것 같다. 하지만 처음에 언어적인 면에서...
# 1  I did have some culture shock during my first ...
# 2  특별히 culture shock이라기 보다는 정말 다양한 문화를 접하는 것 자체가 ...
#
#                                            help_info  \
# 0  살바도르 대학교 국제처에서 비자문제나 숙소문제(홈스테이경우) 등은 해결해 주고, 특...
# 1  I was helped a lot, especially during the firs...
# 2  수업관련해서는 교수님께 질문을 해도 친절하게 알려주시고, 또 교내에 과제나 발표준비...
#
#                                             etc_info
# 0                                                NaN
# 1  Overall, my stay in Australia has been nothing...
# 2  Bond와 그 동네를 생각하면 여유롭고 평화로웠던 분위기가 아직도 생생해요. 여기서...

# %%
# 위의 설정으로 간단하게 보는 df_specific
df_specific.tail(3)
# Out:
#          대학코드                    대학명  \
# 467  US000273    Westminster College
# 468  US000274      Whitworth College
# 469  US000278  Wittenberg University
#
#                                               gen_info  \
# 467  Westminster College는 미국 펜실베니아 주 북부에 있는 작은 마을, ...
# 468  내가 다녀온 교환대학은 Washington State 에 위치한 Whitworth ...
# 469  Wittenberg는 Ohio주의 작은 도시 Springfield에 위치해 있다. ...
#
#                                               env_info  \
# 467  웨스트민스터가 위치한 뉴윌밍턴은 매우 작은 마을입니다. 마음만 먹으면 주말에 산책을...
# 468  Whitworth College는 Seattle에서 비행기로 40분 정도 떨어져 있...
# 469  Springfield의 downtown에는 우체국, 은행(huntington) 정도...
#
#                                              food_info  \
# 467  제가 있던 학기에는 연세대학교에서 온 학생이 총 여학생 3명이어서 모두 같은 기숙사...
# 468  나는 Whitworth College에서 기숙사에 살았다. ISEP으로 가게 되면 ...
# 469  1,2학년과 국제학생들 (1년 이하로 있는 학생들)은 모두 기숙사에서 생활하게 된다...
#
#                                             study_info  \
# 467  저는 한 학기 동안 5과목, 총 15학점을 들었습니다. 정치학 전공 Internat...
# 468  내가 미국에 가기 전에 가장 두려워했던 것은 바로 수업이었다. 어학연수와는 달리 교...
# 469  도서관은 Thomas library가 main이고 다른 단과대학 건물에 독서실이 있...
#
#                                            office_info  \
# 467  웨스트민스터는 국제 학생의 수가 매우 적어서 국제교육부가 따로 있지는 않았습니다. ...
# 468  이 학교에서 내가 마음 편하게 지낼 수 있었던 것은 국제교육부 스텝들이 너무 따뜻하...
# 469  국제교류부는 Hollenbeck 건물 1층에 있는데, Joann 과 Betsy 두 ...
#
#                                             facil_info  \
# 467  제가 가장 자주 이용했던 곳은 클럽룸입니다. 이곳은 맥켈비 센터 2층 구석에 있는 ...
# 468  기타 학교의 부대 시설로는 fitness center, music hall, soc...
# 469  Wittenberg의 가장 큰 장점. nWittenberg는 학비가 무척 비싼 학교...
#
#                                              mhct_info  \
# 467  학교가 위치한 동네에서는 학교 학생들을 제외하면 거의 모든 주민이 백인이었습니다. ...
# 468                                                NaN
# 469  한국에서는 흔치 않은 gay, lesbian, transgender 등을 만날 수 ...
#
#                                              help_info  \
# 467  학교 생활 중 가장 도움을 많이 받을 수 있었던 곳은 교목실의 Internation...
# 468                                                NaN
# 469  Wittenberg는 국제학생들에게 host family를 붙여준다. 비록 같이 살...
#
#                                               etc_info
# 467  그림 같은 호수, 끝없이 넓은 하늘과 함께 따뜻한 단풍색으로 물든 웨스트민스터에서 ...
# 468  처음에 Whitworth College를 ISEP으로부터 배정 받았을 때 현실적으로...
# 469  이처럼 wittenberg는 시골에 있는 작은 학교지만 지리적인 위치로 인한 단점보...

# %%
df_specific.shape
# Out:
# (470, 11)

# %% [markdown]
# ## Select data by position(iloc) or by column value(loc})
# ## 데이터 뽑아내는 방식

# %%
# pandas 설정: 각 column 별 (혹은 한 cell에서) 출력되는 글자수 제한을 없애기
pd.set_option('display.max_colwidth', None)

# %%
column_data = "env_info"
univ_code = "DK000003"

# %%
# 순번으로 대학 데이터 뽑아내고 df -> object로 바꾸기
index = 20
object_example = df_specific[column_data].iloc[index:index+1]
object_example
# Out:
# 20    학교 주변에는 대학 건물과 기숙사 외에는 공장 건물과 마트들 뿐입니다. 약간 휄하다고 느낄 수는 있지만, 저는 조용하고 좋았어요. 하지만 G버스를 타고 10분, 15분 정도 가면 시내로 갈 수 있는데, 음식점, 옷가게, 시청 등등이 있습니다. G버스는 학생증이 있으면 무료이므로 장보러 갈 때나 시내에 나갈 때 G버스를 타시면 편하실 거예요. 비너노이슈타트는 수도인 빈에서 약 40분 정도 떨어져 있는 작은 마을입니다. 학교와 기숙사는 8-10분이면 갈 수 있고 주변에는 사실 유럽이라고 느껴지지는 않을 만큼, 갈대와 공장 몇 개 정도밖에 없어요 그래도 조금 걷거나 학생증이 있으면 무료로 탈 수 있는 G버스를 타면 마트도 금방 갈 수 있고, 도시의 가장 중심부인 City center까지도 15분 정도면 갈 수 있습니다. City center에서 5분 정도면 중앙기차역(Haupbahnhof)도 갈 수 있어서 아마 지내시는 동안 거의 이 G버스만 이용하셔도 될 거에요. 학생증만 있으면 무료이니 매우 편리합니다. 가끔 버스가 늦게 오기도 하니까 여행을 목적으로 중앙역 가실 때에는 넉넉히 시간을 잡고 가시는 것을 추천합니다. 버스보다 빠른 교통수단은 기차가 있는데요. 학교 뒷편으로 Civitasnova라는 간이역?이 있어요. OBB 어플리케이션에서 출발을 Civitasnova로 하시면 중앙역에 2분만에 도착할 수 있습니다. ... 가시거리 안에서는 정말 딱 대학교랑 기숙사 밖에 없어요. 그렇지만 20분 정도 걸으면 장 볼 수 있는 마트(LIDL)랑 드럭스토어가 있습니다. 맥도날드랑 버거킹이랑 수영장도 가까이 있습니다. G 버스라는 학생 무료 버스를 타면 시티센터에 갈 수 있고 시티센터에는 더 많은 마트(BILLA , SPAR)와 옷가게, 음식점, 바 등등이 있습니다. 쇼핑센터에 일식집도 있어서 가끔씩 오는 아시아 음식에 대한 그리움을 잘 달랬습니다! 기차역은 G버스로 가는 비너노이슈타트 중앙역과 간이역 같이 생긴 도보거리에 있는 역이 있어서 교통편은 크게 걱정하지 않으셔도 될 것 같아요ㅎㅎ 대학 주변에는 거의 친환경 공장, 회사들만 있고 아무것도 없습니다. 한 15분 거리?에 맥도날드랑 버거킹 있고, 저렴한 아시안 뷔페도 하나 있습니다. 마트랑 영화관 모여 있는 곳도 걸어갈 수 있는 거리에 있기는 합니다. 만약 수려한 자연환경에 둘러싸인 오스트리아의 시골 마을을 생각하고 오신다면 오산입니다. 하지만 빈이랑 가깝다는 점 하나만으로도 가치가 있다고 생각합니다. 사람들이 많이 사는 주거지역과 연기가 나지않는 친환경 공장지역이 함께 위치해있습니다. 거주하는 사람들이 많은 편이라 그런지 대규모 슈퍼들이 굉장히 다양하고 많아서 장을 보기에는 굉장히 좋습니다. 걸어서 마트에 가면 항상 엄청나게 저렴한 물가에 감탄하면서 먹을 양식을 거침없이 살 수 있습니다. 그리고 대학 주변이 굉장히 조용하고 한적해서 산책하기에 좋고 자전거도 항상 빌려탈 수가 있어서 굉장히 편리합니다. 학교는 도심 및 주거지역에서 떨어진 곳에 위치해있었습니다. 유럽의 전형적인 아기자기한 마을과는 다른 모습으로, 캠퍼스 주위는 허허벌판이었지만 저멀리 둘러싼 설산을 보면 신비한 분위기가 느껴지기도 합니다. 학생증을 보여주면 무료로 탈 수 있는 G버스를 타고 10여분을 가다보면 공원도 있고, 마트도 몇 군데 있습니다. 날씨가 좋은 날은 공원에서 산책을 하기도 하고 시내에서 파르페를 먹기도 했습니다. 시내는 버스로 15분쯤 떨어져있는데, 관공서, 마트, 음식점, 카페, 옷가게 등이 모여있습니다. 주말엔 포장마차같은 곳에서 볶음밥이나 케밥을 사먹기도 하고 드러그스토어나 H&M같은 옷가게에서 쇼핑을 했습니다. 대학 주변 환경은 사실 처음 가면 많이 실망할것이다. 학교가 industrial zone에 위치해 있어서 오스트리아의 예쁜 풍경을 기대할 수는 없기 때문이다. 그리고 학교주변에 휑할만큼 아무것도 없다. 하지만 결국 있을 것은 다있다!! 결론적으로 말하면 학교가 놀것이 엄청많고 제반시설이 엄청많은 도시에 위치해있지 않아서 나는 개인적으로 더 좋았다. 같이 교환온 친구들을 더 묶어주었기 때문이다. 학교주변에 우리만 있는 느낌도 좋았고 계속 함께 같이 할 activity나 놀곳을 찾았기 때문에 더 친해질 수 있는 환경이었다. 학교학생증을 내면 무료로 탈수있는 G 라인 버스를 타고 조금만 나가면 시내에 도착하면 이곳에는 옷집, 레스토랑, 생필품을 살수 있는 광장이 있고 여기에 크리스마스 마켓도 열린다. 또 식료품을 살 수 있는 lidl, hoffer, fishermarket 등등 많은 체인점 마켓들이 버스를 타면 금방 도착 한다 :) 또 술집, 교환학생들이 자주가는 karaoke b... FH는 비너노이슈타트의 교외지역에 위치해있어서 매우 시골처럼 느껴집니다. 비너노이슈타트 시내를 도는 G버스가 30분 정도의 간격으로 오는데 학교가 하는 날에 학생증을 제시하면 무료로 이용할 수 있습니다. 버스를 타면 30분 정도면 시내와 중앙기차역(Hauptbahnhof)에 갈 수 있고 10분 정도면 마트들이 많은 쪽에 갈 수 있습니다. 그곳은 걸어서 20분 정도 걸리는 곳이라 장을 보러 갈 때는 주로 걸어다녔습니다. 기숙사에서 10분 거리에 비너노이슈타트 시비타스 노바(Wiener Neustadt Civitas Nova), 20분 거리에 비너노이슈타트 북역(Wiener Neustadt Nord)이 있는데 이곳에 전철(S-bahn)이 정차하기 때문에 자주 이용했습니다. 앞서 말씀드렸듯 주변에 별 다른 시설이 없습니다. 저녁에는 걸어서 10~15분 거리에 있는 주유소 말고 여는 곳도 없어요. 물론 City Center에 있는 바, 클럽 등은 갈 수 있지만 비싸구요. 다들 기숙사 건물 로비나 복도에서 모여 놀아요. 매우 안전합니다. 저녁에 나가서 산책하고 와도 될 정도로 ^^nn 기숙사에서 걸어서 10분 정도 가면 수영장이 있어요. 학생증 제시하면 매우 싸게 이용할 수 있구요, 시간 나실때 걸어서 여기저기 가 보세요. 15분 정도 걸어나가면 공원도 있고, 식물이나 목재 파는 큰 가게도 있고... 구경하기 좋아요. 대학주변에 많은 것이 있지는 않습니다. 학교와 기숙사는 걸어서 10분이내에 있으며 기숙사 가까운 곳에 수영장이 있습니다. 도시의 중심부라고 할 수 있는 기차역과 센터는 버스를 타고 나가며, 걸으면 30-40분 정도 걸립니다. 센터에는 많은 마트와 식당과 펍, 옷가게 등이 있습니다. 기숙사에서 걸어갈 수 있는 거리에 Billa, Hofer, Lidl 등 다양한 마트가 있으며 맥도날드와 버거킹도 조금 걸으면 갈 수 있습니다. 우선 비너노이슈타트의 시내는 G버스라인으로 10분 정도 떨어진 곳에 위치합니다. 학생증을 제시하면 G라인만 무료로 이용할 수 있습니다. 시내에는 Billa, Spar라는 식료품점이 있습니다. 여행을 가기 위해선 기차역을 반드시 지나쳐야 하는데 기차역은 기숙사에서 버스로 5분 정도 떨어진 곳에 위치합니다. 역시 G라인을 이용하면 무료로 갈 수 있습니다. 하지만 G라인 버스는 저녁 7시에 끊깁니다. 아니면 기숙사에서 20분정도 걸으면 역시 Hoffer, Euro spar, 또 하나의 마트가 있습니다. 유럽에서 살면 살이 찌기 쉽기 때문에 일부러 산책 겸 장을 보러 걸어서 다녀오곤 했습니다. Wiener Neustadt는 작은 도시인데요, 학교는 기숙사와 10분정도 거리에 위치해 있습니다. 학교와 기숙사는 걸어서 10분정도 거리에 위치해 있습니다. G버스라고 해서 학생증을 제시하면 무료로 이용할 수 있는 버스가 있습니다. 버스는 30분에 한대씩 운행합니다. 버스 타고 시내에 나가면 은행, 시청, 식료품점 등이 있습니다. 제가 머무는 동안은 날이 점점 풀리면서 시내중심지에서 종종 장이 열리곤 했습니다. 그리고 기차역과 시내도 멀지 않아서 기차역에서 시내 걸어가는 동안에도 음식점이나 쇼핑할 수 있는 상점들이 있습니다. Wiener Neustadt는 그리 크지 않은 도시입니다. 학교가 있는 주변에는 기숙사가 있고 15분정도 떨어진 위치에 쇼핑을 할 수 있는 곳이 있습니다. 학교주변에서 이용할만한 식당은 케밥집 하나정도 입니다. 버스를 타고 20분 정도 가면 도시의 중심가가 있습니다. 그 ...
# Name: env_info, dtype: object

# %%
# 순번으로 대학 데이터 뽑아내고 object -> string으로 바꾸기
str_example = object_example[index]
str_example
# Out:
# '학교 주변에는 대학 건물과 기숙사 외에는 공장 건물과 마트들 뿐입니다. 약간 휄하다고 느낄 수는 있지만, 저는 조용하고 좋았어요. 하지만 G버스를 타고 10분, 15분 정도 가면 시내로 갈 수 있는데, 음식점, 옷가게, 시청 등등이 있습니다. G버스는 학생증이 있으면 무료이므로 장보러 갈 때나 시내에 나갈 때 G버스를 타시면 편하실 거예요. 비너노이슈타트는 수도인 빈에서 약 40분 정도 떨어져 있는 작은 마을입니다. 학교와 기숙사는 8-10분이면 갈 수 있고 주변에는 사실 유럽이라고 느껴지지는 않을 만큼, 갈대와 공장 몇 개 정도밖에 없어요 그래도 조금 걷거나 학생증이 있으면 무료로 탈 수 있는 G버스를 타면 마트도 금방 갈 수 있고, 도시의 가장 중심부인 City center까지도 15분 정도면 갈 수 있습니다. City center에서 5분 정도면 중앙기차역(Haupbahnhof)도 갈 수 있어서 아마 지내시는 동안 거의 이 G버스만 이용하셔도 될 거에요. 학생증만 있으면 무료이니 매우 편리합니다. 가끔 버스가 늦게 오기도 하니까 여행을 목적으로 중앙역 가실 때에는 넉넉히 시간을 잡고 가시는 것을 추천합니다. 버스보다 빠른 교통수단은 기차가 있는데요. 학교 뒷편으로 Civitasnova라는 간이역?이 있어요. OBB 어플리케이션에서 출발을 Civitasnova로 하시면 중앙역에 2분만에 도착할 수 있습니다. ... 가시거리 안에서는 정말 딱 대학교랑 기숙사 밖에 없어요. 그렇지만 20분 정도 걸으면 장 볼 수 있는 마트(LIDL)랑 드럭스토어가 있습니다. 맥도날드랑 버거킹이랑 수영장도 가까이 있습니다. G 버스라는 학생 무료 버스를 타면 시티센터에 갈 수 있고 시티센터에는 더 많은 마트(BILLA , SPAR)와 옷가게, 음식점, 바 등등이 있습니다. 쇼핑센터에 일식집도 있어서 가끔씩 오는 아시아 음식에 대한 그리움을 잘 달랬습니다! 기차역은 G버스로 가는 비너노이슈타트 중앙역과 간이역 같이 생긴 도보거리에 있는 역이 있어서 교통편은 크게 걱정하지 않으셔도 될 것 같아요ㅎㅎ 대학 주변에는 거의 친환경 공장, 회사들만 있고 아무것도 없습니다. 한 15분 거리?에 맥도날드랑 버거킹 있고, 저렴한 아시안 뷔페도 하나 있습니다. 마트랑 영화관 모여 있는 곳도 걸어갈 수 있는 거리에 있기는 합니다. 만약 수려한 자연환경에 둘러싸인 오스트리아의 시골 마을을 생각하고 오신다면 오산입니다. 하지만 빈이랑 가깝다는 점 하나만으로도 가치가 있다고 생각합니다. 사람들이 많이 사는 주거지역과 연기가 나지않는 친환경 공장지역이 함께 위치해있습니다. 거주하는 사람들이 많은 편이라 그런지 대규모 슈퍼들이 굉장히 다양하고 많아서 장을 보기에는 굉장히 좋습니다. 걸어서 마트에 가면 항상 엄청나게 저렴한 물가에 감탄하면서 먹을 양식을 거침없이 살 수 있습니다. 그리고 대학 주변이 굉장히 조용하고 한적해서 산책하기에 좋고 자전거도 항상 빌려탈 수가 있어서 굉장히 편리합니다. 학교는 도심 및 주거지역에서 떨어진 곳에 위치해있었습니다. 유럽의 전형적인 아기자기한 마을과는 다른 모습으로, 캠퍼스 주위는 허허벌판이었지만 저멀리 둘러싼 설산을 보면 신비한 분위기가 느껴지기도 합니다. 학생증을 보여주면 무료로 탈 수 있는 G버스를 타고 10여분을 가다보면 공원도 있고, 마트도 몇 군데 있습니다. 날씨가 좋은 날은 공원에서 산책을 하기도 하고 시내에서 파르페를 먹기도 했습니다. 시내는 버스로 15분쯤 떨어져있는데, 관공서, 마트, 음식점, 카페, 옷가게 등이 모여있습니다. 주말엔 포장마차같은 곳에서 볶음밥이나 케밥을 사먹기도 하고 드러그스토어나 H&M같은 옷가게에서 쇼핑을 했습니다. 대학 주변 환경은 사실 처음 가면 많이 실망할것이다. 학교가 industrial zone에 위치해 있어서 오스트리아의 예쁜 풍경을 기대할 수는 없기 때문이다. 그리고 학교주변에 휑할만큼 아무것도 없다. 하지만 결국 있을 것은 다있다!! 결론적으로 말하면 학교가 놀것이 엄청많고 제반시설이 엄청많은 도시에 위치해있지 않아서 나는 개인적으로 더 좋았다. 같이 교환온 친구들을 더 묶어주었기 때문이다. 학교주변에 우리만 있는 느낌도 좋았고 계속 함께 같이 할 activity나 놀곳을 찾았기 때문에 더 친해질 수 있는 환경이었다. 학교학생증을 내면 무료로 탈수있는 G 라인 버스를 타고 조금만 나가면 시내에 도착하면 이곳에는 옷집, 레스토랑, 생필품을 살수 있는 광장이 있고 여기에 크리스마스 마켓도 열린다. 또 식료품을 살 수 있는 lidl, hoffer, fishermarket 등등 많은 체인점 마켓들이 버스를 타면 금방 도착 한다 :) 또 술집, 교환학생들이 자주가는 karaoke b... FH는 비너노이슈타트의 교외지역에 위치해있어서 매우 시골처럼 느껴집니다. 비너노이슈타트 시내를 도는 G버스가 30분 정도의 간격으로 오는데 학교가 하는 날에 학생증을 제시하면 무료로 이용할 수 있습니다. 버스를 타면 30분 정도면 시내와 중앙기차역(Hauptbahnhof)에 갈 수 있고 10분 정도면 마트들이 많은 쪽에 갈 수 있습니다. 그곳은 걸어서 20분 정도 걸리는 곳이라 장을 보러 갈 때는 주로 걸어다녔습니다. 기숙사에서 10분 거리에 비너노이슈타트 시비타스 노바(Wiener Neustadt Civitas Nova), 20분 거리에 비너노이슈타트 북역(Wiener Neustadt Nord)이 있는데 이곳에 전철(S-bahn)이 정차하기 때문에 자주 이용했습니다. 앞서 말씀드렸듯 주변에 별 다른 시설이 없습니다. 저녁에는 걸어서 10~15분 거리에 있는 주유소 말고 여는 곳도 없어요. 물론 City Center에 있는 바, 클럽 등은 갈 수 있지만 비싸구요. 다들 기숙사 건물 로비나 복도에서 모여 놀아요. 매우 안전합니다. 저녁에 나가서 산책하고 와도 될 정도로 ^^nn 기숙사에서 걸어서 10분 정도 가면 수영장이 있어요. 학생증 제시하면 매우 싸게 이용할 수 있구요, 시간 나실때 걸어서 여기저기 가 보세요. 15분 정도 걸어나가면 공원도 있고, 식물이나 목재 파는 큰 가게도 있고... 구경하기 좋아요. 대학주변에 많은 것이 있지는 않습니다. 학교와 기숙사는 걸어서 10분이내에 있으며 기숙사 가까운 곳에 수영장이 있습니다. 도시의 중심부라고 할 수 있는 기차역과 센터는 버스를 타고 나가며, 걸으면 30-40분 정도 걸립니다. 센터에는 많은 마트와 식당과 펍, 옷가게 등이 있습니다. 기숙사에서 걸어갈 수 있는 거리에 Billa, Hofer, Lidl 등 다양한 마트가 있으며 맥도날드와 버거킹도 조금 걸으면 갈 수 있습니다. 우선 비너노이슈타트의 시내는 G버스라인으로 10분 정도 떨어진 곳에 위치합니다. 학생증을 제시하면 G라인만 무료로 이용할 수 있습니다. 시내에는 Billa, Spar라는 식료품점이 있습니다. 여행을 가기 위해선 기차역을 반드시 지나쳐야 하는데 기차역은 기숙사에서 버스로 5분 정도 떨어진 곳에 위치합니다. 역시 G라인을 이용하면 무료로 갈 수 있습니다. 하지만 G라인 버스는 저녁 7시에 끊깁니다. 아니면 기숙사에서 20분정도 걸으면 역시 Hoffer, Euro spar, 또 하나의 마트가 있습니다. 유럽에서 살면 살이 찌기 쉽기 때문에 일부러 산책 겸 장을 보러 걸어서 다녀오곤 했습니다. Wiener Neustadt는 작은 도시인데요, 학교는 기숙사와 10분정도 거리에 위치해 있습니다. 학교와 기숙사는 걸어서 10분정도 거리에 위치해 있습니다. G버스라고 해서 학생증을 제시하면 무료로 이용할 수 있는 버스가 있습니다. 버스는 30분에 한대씩 운행합니다. 버스 타고 시내에 나가면 은행, 시청, 식료품점 등이 있습니다. 제가 머무는 동안은 날이 점점 풀리면서 시내중심지에서 종종 장이 열리곤 했습니다. 그리고 기차역과 시내도 멀지 않아서 기차역에서 시내 걸어가는 동안에도 음식점이나 쇼핑할 수 있는 상점들이 있습니다. Wiener Neustadt는 그리 크지 않은 도시입니다. 학교가 있는 주변에는 기숙사가 있고 15분정도 떨어진 위치에 쇼핑을 할 수 있는 곳이 있습니다. 학교주변에서 이용할만한 식당은 케밥집 하나정도 입니다. 버스를 타고 20분 정도 가면 도시의 중심가가 있습니다. 그곳에 은행 ...

# %%
# 대학명으로 대학 데이터 뽑아내고 df -> object로 바꾸기
df_row = df_specific.loc[df_specific["대학코드"] == univ_code]

# %%
str_example = df_row[column_data].to_string(index=False).lstrip()
type(str_example), str_example
# Out:
# 대학 캠퍼스의 경우 시내 중심에 위치해있어서 주변에 이것저것 많습니다. 사회과학대 캠퍼스에서 공부하시는게 아니라면 대학 주변 환경/시설은 기본적인 것들만 있다고 생각하시면 될 것 같습니다. NaN 여러 캠퍼스들이 도시 곳곳에 흩어져 있는 만큼, 캠퍼스 주변은 우리가 일반적으로 생각할 수 있는 도시의 모습이었습니다. 제가 수업을 들었던 South Campus와 CSS 모두 메트로 역에서 멀지 않은 곳에 위치해 있었고, 근처에 마트와 음식점, 각종 가게들이 많았습니다. 다만 South Campus 같은 경우는 시내 중심가에 위치한 CSS에 비해 훨씬 조용한 편이었습니다. 코펜하겐 시내는 대중교통도 굉장히 잘 되어 있고, 마트도 많습니다. 그리고 이런저런 상점들도 많기 때문에 불편하다거나 한 것은 전혀 없었습니다. 작은 도시여서 도보로 이동하기에도 좋고요. 도시 곳곳에 있다보니 주변에 뭐가 있다! 라고 확실하게 말할 수는 없지만 코펜하겐은 도시 자체가 한적하고 평화로운 분위기라고 보면 됩니다. 학교 주변은 어느 캠퍼스냐에 따라서 물론 다르지만 제가 다녔던 사회대 CSS와 인문대 KUA를 중심으로 말씀드릴게요. CSS는 시내 중심부와 거기에 있는 Nørreport 역에 가까이 있어요! 학교 뒷편으로는 바로 길쭉한 호수(?)가 있는데 정말 정말 정말 예쁩니다. 제가 코펜하겐에서 가장 좋아하던 장소들 중 하나에요 :) 특히 여름에는 날이 정말 맑아서 시간대에 따라 하늘 색이 변하는 걸 시시각각 볼 수 있는데 저는 그게 좋아서 몇 시간이고 앉아있었어요, 친구들이랑 맥주 마시기도 정말 좋고요! 학교에서 호수를 지나 올라가면 Nørrebro 지역인데 그 쪽은 주거지역이라 시내에 비해서 케밥이나 길거리 음식 가격이 저렴해요.(물론 한국과는 비교를 하시면 안됩니다…) 제 기숙사도 그 쪽에 있어서 저는 바쁠 때 케밥집들 애용했어요!KUA는 위에서 설명드린 시내 중심을 지나고 Nyhavn이나 Christiansborg 등 관광지도 지나 더 남쪽 Amager라는 신도시를 향해서 가는 ... 대학 주변 환경은 신촌과 홍대를 생각하시면 아니된다는 말씀을 제일 먼저 드리고 싶어요. 제일 번화한 곳, 관광객이 많이 오는 여름철에도 한국과 비교해 매우 여유로웠던 코펜하겐이 생각나네요. 지하철과 버스는 사람이 많아서 조금 붐볐지만, 한국의 대학생이자 통학러라면 능히 이겨낼 수 있는 혼잡함이라고 감히 말씀드립니다. 사람에 밀려다니고 발바닥부터 심장 밑바닥까지 울려오는 음악이 좋으신 분이라면 매우 힘든 주변환경이겠지만, 쉼과 휴식이 필요하셨다면 아주 좋은 주변 환경입니다. 신촌보다는 송도와 같은 조용하고 여유로운 환경입니다. 앞서 교환대학의 크기에서 살짝 말씀드렸듯 도시에 흩어져 있는 캠퍼스가 다 메트로역 가까이 교통이 편한 시내중심지입니다. 그래서 어느 기숙사에 사시든지 통학에 불편은 거의 없으시리라 생각합니다. 자전거를 잘 타시는 분이라면 중고 자전거를 구매하시거나 기숙사 자전거를 빌리시길 추천합니다. 자전거길이 정말 잘 되어있는 도시입니다. 제 친구의 얘기를 빌리자면 사... CSS 주변 Nørreport는 쇼핑거리, 식당, 카페가 많아 관광객 뿐아니라 현지인들도 많이 찾는 곳입니다. 이 곳엔 Studenthuset이라고 코펜하겐 대학교에서 운영하는 카페이자 pub이자 자치활동을 운영하는 곳이 있습니다. 학기 초 파티뿐 아니라 매주 열리는 많은 행사가 이루어지는 장소입니다. 학생증을 소지하고 있으면 가격 할인을 해주기 때문에 저는 과제를 할 때 많이 이용했습니다. 뿐만 아니라 CSS 뒷편에 강 같이 생긴 호수가 있는데, 날씨가 좋을 때 이곳에서 산책을 하거나 커피를 마시면서 기분전환하기 매우 좋은 곳입니다. 그리고 또한 근처에 King\'s garden이라는 공원도 있어 휴식을 취하기 좋습니다.사실 코펜하겐 자체가 큰 도시가 아니고 캠퍼스가 여러개다 보니 대학 주변 환경이 곧 코펜하겐 시내이기 때문에 자세한 설명은 생략하겠습니다. 제가 다녔던 인문대 캠퍼스(Sondre Campus)는 지하철역 Islands Brygge에서 도보로 5분 정도 떨어져 있는, 최신식의 인문대/법대 캠퍼스 입니다. 학교 안에 3개의 카페테리아(kantine)가 있고 덴마크 평균 물가에 비하면 구내 식당의 음식값은 합리적인 편이기 때문에 수업이 있는 날은 많은 학생들이 학교에서 점심을 해결합니다. 학교로 들어오는 입구에 편의점이 하나 있고, 학교에서 자전거로 5-10분 거리에 중심 시가지가 위치해 있습니다. 인문대 캠퍼스는 근처에 다른 학교 캠퍼스, 주택가, 그리고 기숙사(tiengen)가 위치하고 있어 소음이나 공해로부터 자유롭습니다. 다만 제가 다니고 있을 때(2017년 봄학기 기준) 인문대 캠퍼스 일부가 공사 중에 있어 기존에 건물로 들어서던 길이 막혀 다소 불편한 점은 있었습니다. 사회과학대가 위치해 있는 City Campus(CSS)는 바로 옆에 거대한 art museum도 있고 걸어서 5분 정도 거리에 중심 시가... 저는 주로 시내 중심부에 위치한 사회과학대학 캠퍼스(CSS)에 다녔는데, 캠퍼스 바로 앞에 학교에서 관리하는 botanical garden과 도서관 등이 있습니다. 그리고 가까운 곳에 코펜하겐에서 가장 큰 번화가 중 하나인 Nørreport역 주변 거리가 위치합니다. 또한 역 바로 뒤편에는 Torvehallerne이라는 시장(?)이 있어 다양한 식재료와 음식, 특히 아시안 마켓에서 한국 식품들을 구매하실 수도 있습니다. 시내 곳곳에 분포된 박물관이나 성 등도 이 캠퍼스에서 가까워 수업이 끝나고 언제든지 방문하실 수 있습니다.방학 중의 덴마크어 수업과 본 학기 중 인문대학 수업이 이루어지는 남쪽 캠퍼스(KUA)는 CSS에서 자전거로 15-20분 정도 거리에 위치하는데, 매립된 이후 지속적으로 발전이 이루어지고 있는 지구라 시내 중심구의 역사가 깊은 건물들과 달리 혁신적인 디자인의 건물들을 많이 발견하실 수 있습니다. 특별한 길거리 음식이 가득한 paper island나 독특한 ... 코펜하겐 대학교는 캠퍼스가 도시 전체에 나누어져 있습니다. 제가 주로 다녔던 곳은 Amager에 있는 KUA 캠퍼스와 도심에 있는 CSS였는데, 구조가 복잡하게 느껴질 수도 있으니 강의실을 미리 찾아가보는 것도 좋을 것 같습니다. 특히 CSS 근처에는 코펜하겐의 유명한 관광지들이 많이 몰려있으니 틈틈이 구경하기도 좋을 것 같네요. Currently there is still construction going on for KUA3 (i.e. the building where the Faculty of Theology will soon be). There isn’t much surrounding the campus. Nearby there are apartments with a large park and lake, along with a building on the way to the metro, where there is a supermarket (Fakta) and the Agency for International Recruitment and Integration (‘Styrelsen for International Rekruttering og Integration’, or ‘SIRI’) where you get your biometric features recorded for your residen... 제가 있었던 Islands Brygge 캠퍼스는 사실 그렇게 크게 상업적으로 발달된 곳이 아니었습니다. 그렇긴 하지만, Islands Brygge같은 경우에는 다리하나만 건너면 Norreport라는 코펜하겐에서 가장 큰 상업적으로 발달한 곳이 있기 때문에 수업이 끝나면 Norreport로 가거나 Norrebro 라는 대중교통로는 버스로만 연결되어 있는 장소가 있는데 거기서 자전거를 이용하여 친구들과 많이 다녔습니다. 이렇게 코펜하겐같은 경우에는 자전거만을 통해서 갈 수 있는 곳이 있기 때문에, 자전거는 생활하면서 꼭 필요한 필수품입니다. An ideal location very near a major metro/train station, a food flea market, a ...

# %%
def access_univ_info(dataframe, column, univ_code):
    df_row = dataframe.loc[dataframe["대학코드"] == univ_code]
    str_univ_info = df_row[column].to_string(index=False).lstrip()
    return str_univ_info

# %%
access_univ_info(df_specific, column_data, univ_code)
# Out:
# 학대학 캠퍼스의 경우 시내 중심에 위치해있어서 주변에 이것저것 많습니다. 사회과학대 캠퍼스에서 공부하시는게 아니라면 대학 주변 환경/시설은 기본적인 것들만 있다고 생각하시면 될 것 같습니다. NaN 여러 캠퍼스들이 도시 곳곳에 흩어져 있는 만큼, 캠퍼스 주변은 우리가 일반적으로 생각할 수 있는 도시의 모습이었습니다. 제가 수업을 들었던 South Campus와 CSS 모두 메트로 역에서 멀지 않은 곳에 위치해 있었고, 근처에 마트와 음식점, 각종 가게들이 많았습니다. 다만 South Campus 같은 경우는 시내 중심가에 위치한 CSS에 비해 훨씬 조용한 편이었습니다. 코펜하겐 시내는 대중교통도 굉장히 잘 되어 있고, 마트도 많습니다. 그리고 이런저런 상점들도 많기 때문에 불편하다거나 한 것은 전혀 없었습니다. 작은 도시여서 도보로 이동하기에도 좋고요. 도시 곳곳에 있다보니 주변에 뭐가 있다! 라고 확실하게 말할 수는 없지만 코펜하겐은 도시 자체가 한적하고 평화로운 분위기라고 보면 됩니다. 학교 주변은 어느 캠퍼스냐에 따라서 물론 다르지만 제가 다녔던 사회대 CSS와 인문대 KUA를 중심으로 말씀드릴게요. CSS는 시내 중심부와 거기에 있는 Nørreport 역에 가까이 있어요! 학교 뒷편으로는 바로 길쭉한 호수(?)가 있는데 정말 정말 정말 예쁩니다. 제가 코펜하겐에서 가장 좋아하던 장소들 중 하나에요 :) 특히 여름에는 날이 정말 맑아서 시간대에 따라 하늘 색이 변하는 걸 시시각각 볼 수 있는데 저는 그게 좋아서 몇 시간이고 앉아있었어요, 친구들이랑 맥주 마시기도 정말 좋고요! 학교에서 호수를 지나 올라가면 Nørrebro 지역인데 그 쪽은 주거지역이라 시내에 비해서 케밥이나 길거리 음식 가격이 저렴해요.(물론 한국과는 비교를 하시면 안됩니다…) 제 기숙사도 그 쪽에 있어서 저는 바쁠 때 케밥집들 애용했어요!KUA는 위에서 설명드린 시내 중심을 지나고 Nyhavn이나 Christiansborg 등 관광지도 지나 더 남쪽 Amager라는 신도시를 향해서 가는 ... 대학 주변 환경은 신촌과 홍대를 생각하시면 아니된다는 말씀을 제일 먼저 드리고 싶어요. 제일 번화한 곳, 관광객이 많이 오는 여름철에도 한국과 비교해 매우 여유로웠던 코펜하겐이 생각나네요. 지하철과 버스는 사람이 많아서 조금 붐볐지만, 한국의 대학생이자 통학러라면 능히 이겨낼 수 있는 혼잡함이라고 감히 말씀드립니다. 사람에 밀려다니고 발바닥부터 심장 밑바닥까지 울려오는 음악이 좋으신 분이라면 매우 힘든 주변환경이겠지만, 쉼과 휴식이 필요하셨다면 아주 좋은 주변 환경입니다. 신촌보다는 송도와 같은 조용하고 여유로운 환경입니다. 앞서 교환대학의 크기에서 살짝 말씀드렸듯 도시에 흩어져 있는 캠퍼스가 다 메트로역 가까이 교통이 편한 시내중심지입니다. 그래서 어느 기숙사에 사시든지 통학에 불편은 거의 없으시리라 생각합니다. 자전거를 잘 타시는 분이라면 중고 자전거를 구매하시거나 기숙사 자전거를 빌리시길 추천합니다. 자전거길이 정말 잘 되어있는 도시입니다. 제 친구의 얘기를 빌리자면 사... CSS 주변 Nørreport는 쇼핑거리, 식당, 카페가 많아 관광객 뿐아니라 현지인들도 많이 찾는 곳입니다. 이 곳엔 Studenthuset이라고 코펜하겐 대학교에서 운영하는 카페이자 pub이자 자치활동을 운영하는 곳이 있습니다. 학기 초 파티뿐 아니라 매주 열리는 많은 행사가 이루어지는 장소입니다. 학생증을 소지하고 있으면 가격 할인을 해주기 때문에 저는 과제를 할 때 많이 이용했습니다. 뿐만 아니라 CSS 뒷편에 강 같이 생긴 호수가 있는데, 날씨가 좋을 때 이곳에서 산책을 하거나 커피를 마시면서 기분전환하기 매우 좋은 곳입니다. 그리고 또한 근처에 King\'s garden이라는 공원도 있어 휴식을 취하기 좋습니다.사실 코펜하겐 자체가 큰 도시가 아니고 캠퍼스가 여러개다 보니 대학 주변 환경이 곧 코펜하겐 시내이기 때문에 자세한 설명은 생략하겠습니다. 제가 다녔던 인문대 캠퍼스(Sondre Campus)는 지하철역 Islands Brygge에서 도보로 5분 정도 떨어져 있는, 최신식의 인문대/법대 캠퍼스 입니다. 학교 안에 3개의 카페테리아(kantine)가 있고 덴마크 평균 물가에 비하면 구내 식당의 음식값은 합리적인 편이기 때문에 수업이 있는 날은 많은 학생들이 학교에서 점심을 해결합니다. 학교로 들어오는 입구에 편의점이 하나 있고, 학교에서 자전거로 5-10분 거리에 중심 시가지가 위치해 있습니다. 인문대 캠퍼스는 근처에 다른 학교 캠퍼스, 주택가, 그리고 기숙사(tiengen)가 위치하고 있어 소음이나 공해로부터 자유롭습니다. 다만 제가 다니고 있을 때(2017년 봄학기 기준) 인문대 캠퍼스 일부가 공사 중에 있어 기존에 건물로 들어서던 길이 막혀 다소 불편한 점은 있었습니다. 사회과학대가 위치해 있는 City Campus(CSS)는 바로 옆에 거대한 art museum도 있고 걸어서 5분 정도 거리에 중심 시가... 저는 주로 시내 중심부에 위치한 사회과학대학 캠퍼스(CSS)에 다녔는데, 캠퍼스 바로 앞에 학교에서 관리하는 botanical garden과 도서관 등이 있습니다. 그리고 가까운 곳에 코펜하겐에서 가장 큰 번화가 중 하나인 Nørreport역 주변 거리가 위치합니다. 또한 역 바로 뒤편에는 Torvehallerne이라는 시장(?)이 있어 다양한 식재료와 음식, 특히 아시안 마켓에서 한국 식품들을 구매하실 수도 있습니다. 시내 곳곳에 분포된 박물관이나 성 등도 이 캠퍼스에서 가까워 수업이 끝나고 언제든지 방문하실 수 있습니다.방학 중의 덴마크어 수업과 본 학기 중 인문대학 수업이 이루어지는 남쪽 캠퍼스(KUA)는 CSS에서 자전거로 15-20분 정도 거리에 위치하는데, 매립된 이후 지속적으로 발전이 이루어지고 있는 지구라 시내 중심구의 역사가 깊은 건물들과 달리 혁신적인 디자인의 건물들을 많이 발견하실 수 있습니다. 특별한 길거리 음식이 가득한 paper island나 독특한 ... 코펜하겐 대학교는 캠퍼스가 도시 전체에 나누어져 있습니다. 제가 주로 다녔던 곳은 Amager에 있는 KUA 캠퍼스와 도심에 있는 CSS였는데, 구조가 복잡하게 느껴질 수도 있으니 강의실을 미리 찾아가보는 것도 좋을 것 같습니다. 특히 CSS 근처에는 코펜하겐의 유명한 관광지들이 많이 몰려있으니 틈틈이 구경하기도 좋을 것 같네요. Currently there is still construction going on for KUA3 (i.e. the building where the Faculty of Theology will soon be). There isn’t much surrounding the campus. Nearby there are apartments with a large park and lake, along with a building on the way to the metro, where there is a supermarket (Fakta) and the Agency for International Recruitment and Integration (‘Styrelsen for International Rekruttering og Integration’, or ‘SIRI’) where you get your biometric features recorded for your residen... 제가 있었던 Islands Brygge 캠퍼스는 사실 그렇게 크게 상업적으로 발달된 곳이 아니었습니다. 그렇긴 하지만, Islands Brygge같은 경우에는 다리하나만 건너면 Norreport라는 코펜하겐에서 가장 큰 상업적으로 발달한 곳이 있기 때문에 수업이 끝나면 Norreport로 가거나 Norrebro 라는 대중교통로는 버스로만 연결되어 있는 장소가 있는데 거기서 자전거를 이용하여 친구들과 많이 다녔습니다. 이렇게 코펜하겐같은 경우에는 자전거만을 통해서 갈 수 있는 곳이 있기 때문에, 자전거는 생활하면서 꼭 필요한 필수품입니다. An ideal location very near a major metro/train station, a food flea market,  ...

# %%
# removing junks from the string data
def remove_junk(str_data):
    str_data = str_data.replace("\\\\n", "")
    str_data = str_data.replace("\\n", "")
    str_data = str_data.replace("\n", "")
    str_data = str_data.replace("\\", "")
    str_data = str_data.replace("\\t", "")

    # replace multiple spaces into single space
    str_data = ' '.join(str_data.split())
    return str_data

# %%
# collecting all column values into one string
def column_to_string(dataframe, column_name: str):
    str_corpus = dataframe[column_name].to_string(index=False).lstrip()
    str_corpus = remove_junk(str_corpus)
    return str_corpus

# %% [markdown]
# ## Tokenization using konlpy for column values
# ### using Mecab pos tagger | Mecab 형태소 분석기 사용하기

# %%
# konlpy 기반 tokenizer 갖고 오기
from konlpy.tag import Mecab
mecab_tokenizer = Mecab()
example_pos_mecab = mecab_tokenizer.pos(str_example, flatten=True)
example_pos_mecab[:10]
# Out:
# [('앞서', 'MAG'),
#  ('말씀', 'NNG'),
#  ('드린', 'VV+ETM'),
#  ('것', 'NNB'),
#  ('처럼', 'JKB'),
#  ('시내', 'NNG'),
#  ('곳곳', 'NNG'),
#  ('에', 'JKB'),
#  ('캠퍼스', 'NNG'),
#  ('가', 'JKS')]

# %%
# collecting all column values into one string
corpus = column_to_string(df_specific, column_data)
print("글자수:", len(corpus))
corpus[:1000]
# Out:
# 글자수: 4010242
# "대학교가 도시 여러곳에 분포하고 있으므로 각기 다르다. 하지만 남녀를 불문하고 부에노스 아이레스에서 밤에 혼자 다니는 것은 위험하다. 낮에는 대체적으로 사람들이 많이 다니므로 위험하지 않지만 외진곳은 피하는 것이 좋다. n학교 건물 주변에 편의점이나 공원등이 곳곳이 있으므로 공강시 이용이 편리하다. The city center, called CIVIC, is 20min walk away from the campus. It's a very nice walk. The streets aren't that crowded and there are a wide range of restaurants in Civic that you can choose, ranging from Mexican, Chinese, American, etc. In Civic there are IKEA, Coles (go-to mall for grocery shopping) and other fashion stores like Cotton On, H&M, etc. Nightclub in Canberra is great, and students' night is every Thursday, not Friday or Saturday. ANU has a very nice responsible drinking cult... 캠퍼스 자체는 자연입니다. 정문에서 걸어서 10분 정도면 Centre라고 생긴지 얼마 안된 큰 쇼핑센터가 있구요. 마트, 영화관, 클럽 등 전부 가까워요. 물론 캔버라 자체가 작은 도시입니다만, 그래서 기숙사에만 거주하신다면 대중교통을 거의 이용할 필요 없다는 장점이 있습니다. 행정 수도기 때문에 웬만한 것은 다 갖추어져있기도 하구요. 또 Burley Griffin이라는 커다란 인공 호수와 아주 가까운데요. 정말 아름다운 호수입니다. 조깅, 자전거 라이딩 도로를 따라 내려가면 작은 들판이 나오는데요 거기서 보았던 노을은 평생 잊을 수 없을 듯 합니다. 대학교 주변에 센터가 있고, 그 곳에"

# %%
# tokenizing sentences into nouns, verbs, etc
# tokenization for mecab: http://openuiz.blogspot.com/2016/07/mecab-ko-dic.html
# %time tokenized_corpus_mecab = mecab_tokenizer.pos(corpus, flatten=True)
print(len(tokenized_corpus_mecab))
tokenized_corpus_mecab[:10]
# Out:
# CPU times: user 5.63 s, sys: 944 ms, total: 6.57 s
# Wall time: 6.56 s
# 1828784
# [('대학교', 'NNG'),
#  ('가', 'JKS'),
#  ('도시', 'MAG'),
#  ('여러', 'MM'),
#  ('곳', 'NNG'),
#  ('에', 'JKB'),
#  ('분포', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('있', 'VX')]

# %%
# collect only nouns into list
# %time nouns_corpus_mecab = mecab_tokenizer.nouns(corpus)
print(len(nouns_corpus_mecab))
nouns_corpus_mecab[:10]
# Out:
# CPU times: user 4.88 s, sys: 180 ms, total: 5.06 s
# Wall time: 5.05 s
# 528967
# ['대학교', '곳', '분포', '남녀', '불문', '부', '노스', '아이레스', '밤', '것']

# %% [markdown]
# ### using Okt pos tagger | Okt 형태소 분석기 사용하기

# %%
# konlpy 기반 Okt tokenizer 갖고 오기
from konlpy.tag import Okt
okt_tokenizer = Okt()
example_pos_okt = okt_tokenizer.pos(str_example, norm=True, stem=True)
example_pos_okt[:10]
# Out:
# [('앞서', 'Noun'),
#  ('말씀드리다', 'Verb'),
#  ('것', 'Noun'),
#  ('처럼', 'Josa'),
#  ('시내', 'Noun'),
#  ('곳곳', 'Noun'),
#  ('에', 'Josa'),
#  ('캠퍼스', 'Noun'),
#  ('가', 'Josa'),
#  ('흩어지다', 'Verb')]

# %%
# tokenizing sentences into nouns, verbs, etc
# tokenization for Okt: https://github.com/open-korean-text/open-korean-text
# %time tokenized_corpus_okt = okt_tokenizer.pos(corpus, norm=True, stem=True, join=False)
print(len(tokenized_corpus_okt))
tokenized_corpus_okt[:10]
# Out:
# CPU times: user 4min 27s, sys: 6.41 s, total: 4min 33s
# Wall time: 2min 58s
# 1493598
# [('대학교', 'Noun'),
#  ('가', 'Josa'),
#  ('도시', 'Noun'),
#  ('여러', 'Modifier'),
#  ('곳', 'Noun'),
#  ('에', 'Josa'),
#  ('분포', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('각기', 'Noun')]

# %%
# collect only nouns into list
# %time nouns_corpus_okt = okt_tokenizer.nouns(corpus)
print(len(nouns_corpus_okt))
nouns_corpus_okt[:10]
# Out:
# CPU times: user 2min 45s, sys: 6.14 s, total: 2min 51s
# Wall time: 1min 44s
# 592228
# ['대학교', '도시', '곳', '분포', '각기', '남녀', '불문', '부', '노스', '아이레스']

# %% [markdown]
# ## Counting words' Frequency Analysis for column values
# ### words divided by Mecab && Okt

# %%
from collections import Counter

# %%
print("number of documents:", len(df_specific[column_data]))
print("number of letters in text corpus:", len(corpus))
print("number of tokenized nouns by mecab:", len(nouns_corpus_mecab))
print("number of tokenized nouns by Okt:", len(nouns_corpus_okt))
# Out:
# number of documents: 470
# number of letters in text corpus: 4010242
# number of tokenized nouns by mecab: 528967
# number of tokenized nouns by Okt: 592228

# %%
# Mecab divided nouns list term frequency
nouns_mecab_counted = Counter(nouns_corpus_mecab)
print("number of counted nouns:", len(nouns_mecab_counted))
nouns_mecab_counted.most_common(50)
# Out:
# number of counted nouns: 13944
# [('수', 16983),
#  ('학교', 14210),
#  ('것', 10136),
#  ('곳', 9775),
#  ('분', 8582),
#  ('주변', 8361),
#  ('등', 7639),
#  ('버스', 7299),
#  ('정도', 6627),
#  ('때문', 5518),
#  ('캠퍼스', 5470),
#  ('거리', 5405),
#  ('도시', 5338),
#  ('위치', 5146),
#  ('학생', 5042),
#  ('대학', 4855),
#  ('이용', 4235),
#  ('음식점', 3525),
#  ('마트', 3517),
#  ('때', 3454),
#  ('근처', 3393),
#  ('차', 3197),
#  ('한국', 3171),
#  ('식당', 3093),
#  ('쇼핑', 3025),
#  ('시간', 2993),
#  ('시내', 2893),
#  ('생활', 2659),
#  ('편', 2603),
#  ('기숙사', 2491),
#  ('번', 2472),
#  ('친구', 2463),
#  ('다운타운', 2450),
#  ('역', 2293),
#  ('내', 2257),
#  ('사람', 2253),
#  ('지역', 2184),
#  ('건물', 2107),
#  ('생각', 2102),
#  ('저', 2075),
#  ('대부분', 2025),
#  ('시설', 1994),
#  ('쇼핑몰', 1978),
#  ('필요', 1973),
#  ('앞', 1973),
#  ('가게', 1916),
#  ('경우', 1876),
#  ('미국', 1862),
#  ('음식', 1775),
#  ('개', 1751)]

# %%
# Okt divided nouns list term frequency
nouns_okt_counted = Counter(nouns_corpus_okt)
print("number of counted nouns:", len(nouns_okt_counted))
nouns_okt_counted.most_common(50)
# Out:
# number of counted nouns: 14863
# [('수', 15079),
#  ('학교', 13977),
#  ('곳', 11631),
#  ('것', 10255),
#  ('주변', 8356),
#  ('등', 7472),
#  ('버스', 7211),
#  ('때문', 5517),
#  ('캠퍼스', 5462),
#  ('거리', 5439),
#  ('정도', 5409),
#  ('위치', 5131),
#  ('도시', 4688),
#  ('이', 4562),
#  ('대학', 4535),
#  ('이용', 4256),
#  ('학생', 4235),
#  ('타고', 4071),
#  ('마트', 3578),
#  ('때', 3414),
#  ('근처', 3393),
#  ('음식점', 3375),
#  ('그', 3250),
#  ('쇼핑', 3109),
#  ('식당', 3088),
#  ('한국', 3077),
#  ('시내', 2808),
#  ('바로', 2515),
#  ('다운타운', 2483),
#  ('기숙사', 2478),
#  ('친구', 2461),
#  ('매우', 2407),
#  ('역', 2387),
#  ('가게', 2276),
#  ('사람', 2233),
#  ('저', 2148),
#  ('가장', 2135),
#  ('번', 2132),
#  ('생활', 2129),
#  ('조금', 2124),
#  ('건물', 2110),
#  ('생각', 2108),
#  ('정말', 2071),
#  ('내', 2065),
#  ('대부분', 2032),
#  ('시설', 2030),
#  ('가면', 2021),
#  ('를', 2020),
#  ('더', 2007),
#  ('쇼핑몰', 1979)]

# %%
# check appearance frequency of a keyword
keyword = "위치"
print(nouns_mecab_counted[keyword], nouns_okt_counted[keyword])
# Out:
# 5146 5131

# %% [markdown]
# ## Generating Wordcloud

# %%
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# 워드클라우드를 위한 나눔고딕 설치
# !apt -qq -y install fonts-nanum > /dev/null

# 워드클라우드를 위한 나눔고딕 경로 설정
import matplotlib.font_manager as fm
fontpath = './font/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
backgroundcolor = "white"
width=800
height=600
wordcloud = WordCloud(font_path = fontpath,
                        # stopwords = STOPWORDS, 
                        background_color = backgroundcolor, 
                        max_words= 50,
                        max_font_size= 300,
                        width = width, 
                        height = height)

# %%
# 빈도수 별로 단어를 크게 표시한다
wordcloud.generate_from_frequencies(frequencies = nouns_mecab_counted) # mecab으로 추출한 명사로 워드클라우드를 그린다.
plt.figure(figsize = (15 , 10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
wordcloud.generate_from_frequencies(frequencies = nouns_okt_counted) # Okt로 추출한 명사로 워드클라우드를 그린다.
plt.figure(figsize = (15 , 10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## 체언, 서술어 위주 키워드 뽑아내기
# ### Okt 형태소 분석기와 mecab 형태소 분석기 동시에 사용

# %%
stopwords = ["대학", "캠퍼스", "학교"]

def mecab_kor_tokenizer(raw, stopwords):
    # position arguments(or position tags): 내가 뽑아내고 싶은 형태소들
    mecab_pos = ["NNG", "NNP", "VV", "VA", "MAG"]
    mecab_list = [
        word
        for word, tag in mecab_tokenizer.pos(raw, flatten=True)
        if len(word) > 1 and tag in mecab_pos and word not in stopwords
    ]

    return mecab_list
    

def okt_kor_tokenizer(raw, stopwords):
    # position arguments(or position tags): 내가 뽑아내고 싶은 형태소들
    twitter_pos = ["Noun", "Alpha", "Verb", "Number", "Adverb"]
    twitter_list = [
        word
        # normalize 그랰ㅋㅋ -> 그래ㅋㅋ  # stemming 바뀌나->바뀌다
        for word, tag in okt_tokenizer.pos(raw, norm=True, stem=True)
        if len(word) > 1 and tag in twitter_pos and word not in stopwords
    ]
    return twitter_list

# combine extracted noun and verb list without overlapping

# %%
okt_kor_tokenizer(corpus, stopwords)
# Out:
# ['대학교',
#  '도시',
#  '분포',
#  '각기',
#  '남녀',
#  '불문',
#  '노스',
#  '아이레스',
#  '혼자',
#  '다니다',
#  '체적',
#  '사람',
#  '많이',
#  '다니다',
#  '않다',
#  '외진',
#  '피하',
#  '건물',
#  '주변',
#  '편의점',
#  '곳곳이',
#  '강시',
#  '이용',
#  'The',
#  'city',
#  'center',
#  'called',
#  'CIVIC',
#  'is',
#  '20',
#  'min',
#  'walk',
#  'away',
#  'from',
#  'the',
#  'campus',
#  'It',
#  'very',
#  'nice',
#  'walk',
#  'The',
#  'streets',
#  'aren',
#  'that',
#  'crowded',
#  'and',
#  'there',
#  'are',
#  'wide',
#  'range',
#  'of',
#  'restaurants',
#  'in',
#  'Civic',
#  'that',
#  'you',
#  'can',
#  'choose',
#  'ranging',
#  'from',
#  'Mexican',
#  'Chinese',
#  'American',
#  'etc',
#  'In',
#  'Civic',
#  'there',
#  'are',
#  'IKEA',
#  'Coles',
#  'go',
#  'to',
#  'mall',
#  'for',
#  'grocery',
#  'shopping',
#  'and',
#  'other',
#  'fashion',
#  'stores',
#  'like',
#  'Cotton',
#  'On',
#  'etc',
#  'Nightclub',
#  'in',
#  'Canberra',
#  'is',
#  'great',
#  'and',
#  'students',
#  'night',
#  'is',
#  'every',
#  'Thursday',
#  'not',
#  'Friday',
#  'or',
#  'Saturday',
#  'ANU',
#  'has',
#  'very',
#  'nice',
#  'responsible',
#  'drinking',
#  'cult',
#  '자체',
#  '자연',
#  '정문',
#  '걸다',
#  '10분',
#  '정도',
#  'Centre',
#  '생기다',
#  '얼마',
#  '크다',
#  '쇼핑',
#  '센터',
#  '마트',
#  '영화관',
#  '클럽',
#  '전부',
#  '물론',
#  '캔버라',
#  '자체',
#  '도시',
#  '그래서',
#  '기숙사',
#  '거주',
#  '하다',
#  '대중교통',
#  '거의',
#  '이용',
#  '하다',
#  '필요',
#  '장점',
#  '행정',
#  '도기',
#  '때문',
#  '갖추다',
#  '기도',
#  '하다',
#  'Burley',
#  'Griffin',
#  '인공',
#  '호수',
#  '아주',
#  '정말',
#  '호수',
#  '조깅',
#  '자전거',
#  '라이딩',
#  '도로',
#  '따르다',
#  '내려가다',
#  '들판',
#  '나오다',
#  '거기',
#  '보다',
#  '노을',
#  '평생',
#  '잊다',
#  '하다',
#  '대학교',
#  '주변',
#  '센터',
#  '술집',
#  '영화관',
#  '카페',
#  '거기',
#  '빼다',
#  '사실',
#  '거리',
#  '않다',
#  '연세대',
#  '주변',
#  '환경',
#  '거의',
#  '반대',
#  '감안',
#  '하다',
#  '갈다',
#  '바라다',
#  '자연',
#  '고요함',
#  '즐기다',
#  '추천',
#  '드리다',
#  'Commonwealth',
#  'park',
#  '공원',
#  '호수',
#  '크다',
#  '추천',
#  '드리다',
#  '정말',
#  '사람',
#  '않다',
#  '정말',
#  'Mount',
#  'Ainslie',
#  '곳도',
#  '추천',
#  '드리다',
#  'Fenner',
#  'hall',
#  '2-30분',
#  '걸어가다',
#  '되다',
#  '나무',
#  '경치',
#  '무엇',
#  '말로',
#  '듣다',
#  '캥거루',
#  '뜯다',
#  '캥거루',
#  '정말',
#  '많이',
#  '우리',
#  '없이',
#  '너무',
#  '가까이',
#  '가지',
#  '않다',
#  '이상',
#  '공격',
#  '하다',
#  '않다',
#  'Botanic',
#  'garden',
#  'Old',
#  'Bus',
#  'Depot',
#  'Markets',
#  '추천',
#  '드리다',
#  '많이',
#  '최대한',
#  '열심히',
#  '찾다',
#  '다니다',
#  '한국',
#  '돌아오다',
#  '자연',
#  '너무',
#  '캔버라',
#  '사실',
#  '도시',
#  '호주',
#  '수도',
#  '정말',
#  '수도',
#  '역할',
#  '하다',
#  '시드니',
#  '뉴욕',
#  '라면',
#  '캔버라',
#  '워싱턴',
#  '정도',
#  '캔버라',
#  '가장',
#  '중심부',
#  '시내',
#  '쇼핑몰',
#  '한국',
#  '코인',
#  '노래방',
#  '음식점',
#  '거리',
#  '크게',
#  '문화',
#  '않다',
#  'TV',
#  '생각',
#  '하다',
#  '유학생',
#  '꿈꾸다',
#  '목요일',
#  '클럽',
#  '무료',
#  '입장',
#  '크다',
#  '쇼핑몰',
#  '별거',
#  '웬만큼',
#  'ANU',
#  'Civic',
#  '걸다',
#  '10~15분',
#  '정도',
#  '아주',
#  '주변',
#  '양식',
#  '비롯',
#  '하다',
#  '여러',
#  '아시아',
#  '한국',
#  '중국',
#  '일본',
#  '베트남',
#  '말레이시아',
#  '식당',
#  '위치',
#  '하다',
#  '참고',
#  '한인',
#  '마트',
#  '정말',
#  '위치',
#  '하다',
#  '캔버라',
#  '센터',
#  '걸다',
#  '15분',
#  '정도',
#  '중심',
#  '않다',
#  '위치',
#  '하다',
#  '캔버라',
#  '자체',
#  '매우',
#  '서울',
#  '붐비다',
#  'night',
#  'life',
#  '시골',
#  '분위기',
#  '불다',
#  '캔버라',
#  '생활',
#  '자다',
#  '생각',
#  '하다',
#  '조금',
#  '떨어지다',
#  '버스',
#  '타고',
#  '가면',
#  'Commonwealth',
#  'park',
#  '가다',
#  '호수',
#  '따르다',
#  '산책',
#  '하다',
#  '즐기다',
#  '하다',
#  'Braddon',
#  'Canberra',
#  'central',
#  '주로',
#  '수업',
#  '끝나다',
#  '친구',
#  '식사',
#  '거나',
#  '쇼핑',
#  '식료품',
#  '사르다',
#  '나가다',
#  '친구',
#  '만나다',
#  'Belconnen',
#  '이나',
#  'Mitchell',
#  'Kingston',
#  '가기',
#  '하다',
#  '캔버라',
#  '가장',
#  'Australian',
#  'War',
#  'Memorial',
#  '또한',
#  'National',
#  'Arboretum',
#  'Botanic',
#  'garden',
#  '이나',
#  'National',
#  'gallery',
#  '시간',
#  '방문',
#  '하다',
#  '캔버라',
#  '중심',
#  '시내',
#  '근처',
#  '사실',
#  '식당',
#  '별거',
#  '캔버라',
#  '자체',
#  '일단',
#  '크다',
#  '도시',
#  '행정도시',
#  '때문',
#  '행정',
#  '건물',
#  '사무실',
#  '않다',
#  '공부',
#  '하다',
#  '최적',
#  '환경',
#  '센터',
#  '시내',
#  '불리다',
#  '군데',
#  '나머지',
#  '버스',
#  '타고',
#  '다니다',
#  '조금',
#  '위치',
#  '하다',
#  '대형',
#  '마트',
#  '음식점',
#  '한인',
#  '마트',
#  '등등',
#  '정도',
#  '주변',
#  '주변',
#  '걸다',
#  '하다',
#  '10분',
#  '정도',
#  '캔버라',
#  '센터',
#  '생활',
#  '대부분',
#  '용품',
#  '아마',
#  '캔버라',
#  '사람',
#  '가장',
#  '하나',
#  '콜스',
#  '이마트',
#  '홈플러스',
#  '엄청',
#  '크다',
#  '마트',
#  '이구',
#  '센터',
#  '엄청',
#  '건물',
#  '우리나라',
#  '위로',
#  '솟다',
#  '않다',
#  '퍼지다',
#  '걷다',
#  '보다',
#  '들어오다',
#  '입구',
#  '아예',
#  '다른',
#  '나오다',
#  '자신',
#  '발견',
#  '하다',
#  '캔버라',
#  '워낙',
#  '도시',
#  '갈다',
#  '모이다',
#  '캔버라',
#  '센터',
#  '주변',
#  '식당',
#  '카페',
#  '몰리다',
#  '센터',
#  '주변',
#  '살짝',
#  '벗어나다',
#  '진짜',
#  '황량',
#  '하다',
#  '한번',
#  '도시',
#  '탐험',
#  '하다',
#  '여기저기',
#  '돌아다니다',
#  '보다',
#  '별것',
#  '추다',
#  '하다',
#  'ANU',
#  '자체',
#  '캔버라',
#  '중심',
#  '위치',
#  '때문',
#  '생활',
#  '하다',
#  '시내',
#  '중심',
#  '가르다',
#  'Civic',
#  '부르다',
#  '식당',
#  '쇼핑몰',
#  '도서관',
#  '영화관',
#  '모든',
#  '시설',
#  '모이다',
#  '한인식',
#  '가보',
#  '않다',
#  '한인식',
#  '군데',
#  '정도',
#  '한인',
#  '마트',
#  'civic',
#  'kim',
#  'grocery',
#  'uni',
#  'pub',
#  '건물',
#  'mart',
#  '한국',
#  '음식',
#  '사먹다',
#  '한국',
#  '택배',
#  '부치다',
#  'kinloch',
#  'lodge',
#  '아시안',
#  '마켓',
#  '한국',
#  '음식',
#  '중국',
#  '동남아',
#  '음식',
#  '때문',
#  '자주',
#  '이용',
#  '하다',
#  '않다',
#  '바로',
#  'Black',
#  'Mountain',
#  'Griffin',
#  'Lake',
#  '주말',
#  '친구',
#  '산책',
#  '나가다',
#  '하다',
#  'One',
#  'thing',
#  'about',
#  'ANU',
#  'is',
#  'that',
#  'always',
#  'felt',
#  'quite',
#  'safe',
#  'despite',
#  'being',
#  'in',
#  'completely',
#  'new',
#  'country',
#  'This',
#  'was',
#  'due',
#  'to',
#  'the',
#  'school',
#  'strict',
#  'provisions',
#  'of',
#  'campus',
#  'safety',
#  'facilities',
#  'such',
#  'as',
#  'an',
#  'ANU',
#  'distress',
#  'call',
#  'app',
#  'ANU',
#  'Security',
#  'Patrols',
#  'and',
#  'most',
#  'significantly',
#  'the',
#  'campus',
#  'shuttle',
#  'buses',
#  'that',
#  'you',
#  'could',
#  'call',
#  'to',
#  'take',
#  'you',
#  'from',
#  'one',
#  'place',
#  'to',
#  'another',
#  'in',
#  'the',
#  'evenings',
#  'or',
#  'during',
#  'the',
#  'day',
#  'This',
#  'not',
#  'only',
#  'provided',
#  'easy',
#  'and',
#  'free',
#  'transport',
#  'from',
#  'one',
#  'spot',
#  'of',
#  'the',
#  'campus',
#  'to',
#  'another',
#  'but',
#  'also',
#  'allows',
#  'for',
#  'you',
#  'to',
#  'stay',
#  'out',
#  'late',
#  '걸다',
#  '15분',
#  '정도',
#  '거리',
#  'Civic',
#  '이르다',
#  '불리다',
#  '번화가',
#  '근처',
#  '편의',
#  '시설',
#  '거의',
#  '주변',
#  '녹지',
#  'Burley',
#  'griffin',
#  '크다',
#  '호수',
#  '인접',
#  '산책',
#  '하다',
#  '매우',
#  '10',
#  '15분',
#  '정도',
#  '걸다',
#  'Civic',
#  '이르다',
#  '불리다',
#  '중심부',
#  '닿다',
#  '각종',
#  '행정기관',
#  '건물',
#  '상점',
#  '모이다',
#  'Civic',
#  '중심부',
#  'Canberra',
#  'Centre',
#  '쇼핑몰',
#  '위치',
#  'Supabarn',
#  'Aldi',
#  '슈퍼마켓',
#  '입점해',
#  '식료품',
#  '구입',
#  '항상',
#  '하다',
#  'Civic',
#  '제외',
#  '하다',
#  '건물',
#  '대부분',
#  '거주지',
#  '혹은',
#  '공원',
#  '또한',
#  '주변',
#  '캔버라',
#  '전체',
#  '자전거',
#  '도로',
#  '아주',
#  '자다',
#  '정리',
#  '되어다',
#  '특히',
#  '얘기',
#  '하다',
#  '떨어지다',
#  '기숙사',
#  '살다',
#  '때문',
#  '등교',
#  '하다',
#  '항상',
#  '자전거',
#  '타다',
#  '하다',
#  '거의',
#  '대부분',
#  '도로',
#  '자전거',
#  '도로',
#  '따로',
#  '자전거',
#  '타고',
#  '다니다',
#  '사람',
#  '아주',
#  '때문',
#  '승용차',
#  '운전자',
#  '항상',
#  '먼저',
#  '양보',
#  '하다',
#  '주다',
#  '자전거',
#  '타다',
#  '정말',
#  '환경',
#  '하다',
#  '주변',
#  '크다',
#  '호수',
#  '블랙',
#  '마운틴',
#  '가든',
#  '인접',
#  '하다',
#  '때문',
#  '주변',
#  '환경',
#  '또한',
#  '교정',
#  '캔버라',
#  '모든',
#  '건물',
#  '때문',
#  '트이다',
#  '느낌',
#  '받다',
#  '캔버라',
#  '계획도시',
#  '만큼',
#  '자전거',
#  '도로',
#  '정말',
#  '매우',
#  '되어다',
#  '자전거',
#  '타고',
#  '캔버라',
#  '일주',
#  '하다',
#  '정도',
#  '정말',
#  '차도',
#  '별로',
#  '자전거',
#  '도로',
#  '자다',
#  '되어다',
#  '정말',
#  '거의',
#  '평지',
#  '이기',
#  '때문',
#  '자전거',
#  '구매',
#  '하다',
#  '추천',
#  '하다',
#  'ANU',
#  '가장',
#  '경험',
#  '자전거',
#  '실컷',
#  '도둑',
#  '때문',
#  '기숙사',
#  '들어가다',
#  '기숙사',
#  '정해진',
#  '자전거',
#  '보관',
#  '넣다',
#  '두다',
#  '자물쇠',
#  '끊다',
#  '가져가다',
#  '종종',
#  '자전거',
#  '중고',
#  '사시',
#  '추천',
#  '드리다',
#  'ANU',
#  '페이스북',
#  '페이지',
#  '하나',
#  '플리',
#  '마켓',
#  '페이지',
#  '싸다',
#  '80달러',
#  '200달러',
#  '사실',
#  '특별',
#  'ANU',
#  '입구',
#  '15분',
#  '거리',
#  'civic',
#  '나름',
#  '번화가',
#  '중심',
#  '거리',
#  '신촌',
#  '하다',
#  '정말',
#  '때문',
#  '여기',
#  '제일',
#  '들다',
#  '직접',
#  '보다',
#  '충격',
#  '받다',
#  'civic',
#  '중심',
#  '캔버라',
#  '센터',
#  '음식',
#  '재료',
#  '생활용품',
#  '비롯',
#  '하다',
#  '가전제품',
#  '구비',
#  '되어다',
#  '음식점',
#  '센터',
#  '중심',
#  '바깥쪽',
#  '여러',
#  '음식점',
#  '카페',
#  '몰리다',
#  '센터',
#  'DENDY',
#  '하다',
#  '영화관',
#  '다만',
#  '모든',
#  '금요일',
#  '제외',
#  '하다',
#  '5시',
#  '거의',
#  '닫다',
#  '때문',
#  '아침',
#  '인간',
#  '되다',
#  '캔버라',
#  '한국',
#  '마트',
#  'civic',
#  '근처',
#  '한국',
#  '음식',
#  '라면',
#  '김치',
#  '국산',
#  '생활용품',
#  '쉬다',
#  '하다',
#  '한국음식점',
#  '가격',
#  '많이',
#  '은행',
#  '먹다',
#  '해결',
#  '하다',
#  '주로',
#  'civic',
#  '나가다',
#  '기숙사',
#  '보통',
#  '20~40분',
#  '정도',
#  '걸다',
#  '자전거',
#  '10분',
#  '나가다',
#  '오다',
#  '자전거',
#  '정말',
#  '펴다',
#  'civic',
#  '조금',
#  '나가다',
#  '크게',
#  '호수',
#  '여행',
#  '다니다',
#  '곳도',
#  '많이',
#  '15분',
#  '정도',
#  '걸다',
#  'Canberra',
#  'Centre',
#  '가다',
#  '거기',
#  '가게',
#  '식료품',
#  '생필품',
#  '모두',
#  '거기',
#  '쉬다',
#  '구입',
#  '하다',
#  'coles',
#  'woolworths',
#  '같이',
#  '슈퍼마켓',
#  '버스',
#  '타고',
#  '하다',
#  '20분',
#  '가야',
#  '나오다',
#  'Belconnen',
#  '이란',
#  '물건',
#  '조금',
#  '싸다',
#  '않다',
#  '이상',
#  'ANU',
#  '대부분',
#  '학생',
#  'Canberra',
#  'Centre',
#  '애용',
#  '하다',
#  '주변',
#  '다른',
#  '동네',
#  '가다',
#  '버스',
#  '빌리다',
#  '타지',
#  '않다',
#  '쉬다',
#  '갈다',
#  '대부분',
#  '장보기',
#  '쇼핑',
#  '15~20분',
#  '정도',
#  '떨어지다',
#  'CIVIC',
#  '센터',
#  ...]
